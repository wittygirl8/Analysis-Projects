# %%
import pandas as pd

# %%
data = pd.read_csv('covid_19_data.csv')

# %%
datas
# Out:
#           Date                     State                  Region  Confirmed  \
# 0    4/29/2020                       NaN             Afghanistan       1939
# 1    4/29/2020                       NaN                 Albania        766
# 2    4/29/2020                       NaN                 Algeria       3848
# 3    4/29/2020                       NaN                 Andorra        743
# 4    4/29/2020                       NaN                  Angola         27
# 5    4/29/2020                       NaN     Antigua and Barbuda         24
# 6    4/29/2020                       NaN               Argentina       4285
# 7    4/29/2020                       NaN                 Armenia       1932
# 8    4/29/2020                       NaN                 Austria      15402
# 9    4/29/2020                       NaN              Azerbaijan       1766
# 10   4/29/2020                       NaN                 Bahamas         80
# ...

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
 data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
#to show these null values in the form of heatmap we will import seaborn library
"""import seaborn as sns
import matplotlib.pyplot as plt

are use for visualization perpose"""
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
 #show the number of Confirmed, Deths and Recovered cases in each region.
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending =  False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
#                         Confirmed  Recovered
# Region
# Afghanistan                  1939        252
# Albania                       766        455
# Algeria                      3848       1702
# Andorra                       743        423
# Angola                         27          7
# Antigua and Barbuda            24         11
# Argentina                    4285       1192
# Armenia                      1932        900
# Australia                    6752       5715
# Austria                     15402      12779
# Azerbaijan                   1766       1267
# Bahamas                        80         23
# Bahrain                      2921       1455
# Bangladesh                   7103        150
# Barbados                       80         39
# Belarus                     13181       2072
# Belgium                     47859      11283
# Belize                         18          9
# Benin                          64         33
# Bhutan                          7          5
# ...

# %%
#remove all the records where Confirmed cases is less then 10
data[data.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
#remove all the records where Confirmed cases is less then 10
data[~(data.Confirmed < 10)]
# Out:
#           Date                     State                  Region  Confirmed  \
# 0    4/29/2020                       NaN             Afghanistan       1939
# 1    4/29/2020                       NaN                 Albania        766
# 2    4/29/2020                       NaN                 Algeria       3848
# 3    4/29/2020                       NaN                 Andorra        743
# 4    4/29/2020                       NaN                  Angola         27
# 5    4/29/2020                       NaN     Antigua and Barbuda         24
# 6    4/29/2020                       NaN               Argentina       4285
# 7    4/29/2020                       NaN                 Armenia       1932
# 8    4/29/2020                       NaN                 Austria      15402
# 9    4/29/2020                       NaN              Azerbaijan       1766
# 10   4/29/2020                       NaN                 Bahamas         80
# ...

# %%
#remove all the records where Confirmed cases is less then 10
data = data[~(data.Confirmed < 10)]
data
# Out:
#           Date                     State                  Region  Confirmed  \
# 0    4/29/2020                       NaN             Afghanistan       1939
# 1    4/29/2020                       NaN                 Albania        766
# 2    4/29/2020                       NaN                 Algeria       3848
# 3    4/29/2020                       NaN                 Andorra        743
# 4    4/29/2020                       NaN                  Angola         27
# 5    4/29/2020                       NaN     Antigua and Barbuda         24
# 6    4/29/2020                       NaN               Argentina       4285
# 7    4/29/2020                       NaN                 Armenia       1932
# 8    4/29/2020                       NaN                 Austria      15402
# 9    4/29/2020                       NaN              Azerbaijan       1766
# 10   4/29/2020                       NaN                 Bahamas         80
# ...

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
#in which region, maximum number of deaths cses were recorded
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
#in which region minimum no. of deaths cases are recorded
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Region
# Laos                        0
# Mongolia                    0
# Mozambique                  0
# Cambodia                    0
# Fiji                        0
# Namibia                     0
# Nepal                       0
# Madagascar                  0
# Macau                       0
# Papua New Guinea            0
# Rwanda                      0
# Saint Kitts and Nevis       0
# Bhutan                      0
# Dominica                    0
# Central African Republic    0
# Saint Lucia                 0
# Holy See                    0
# Sao Tome and Principe       0
# Yemen                       0
# Western Sahara              0
# Name: Deaths, dtype: int64

# %%
#how many confirmed, Deaths & Recovered cases were reported from India till 29 April 2020?
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
#Sort the entire data wrt No. of confirmed cases in ascending order.
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by = ['Confirmed'], acending = True)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 272  4/29/2020             Northwest Territories                 Canada
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# 194  4/29/2020            British Virgin Islands                     UK
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %%
#Sort the entire data wrt No. of Recovered cases in ascending order.
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values( by = ['Recovered'], ascending = 'False').head(20)
# Out:
#           Date                             State            Region  Confirmed  \
# 240  4/29/2020                            Kansas                US       3839
# 279  4/29/2020              Prince Edward Island            Canada         27
# 251  4/29/2020                          Michigan                US      40399
# 193  4/29/2020                  British Columbia            Canada       2087
# 280  4/29/2020                       Puerto Rico                US       1433
# 213  4/29/2020                           Georgia                US      25775
# 249  4/29/2020                     Massachusetts                US      60265
# 199  4/29/2020                          Colorado                US      14758
# 126  4/29/2020                               NaN  Papua New Guinea          8
# 252  4/29/2020                         Minnesota                US       4644
# 248  4/29/2020                          Maryland                US      20849
# ...
