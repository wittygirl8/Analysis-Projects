# %%
"""Working on Real Projet 'London Husing dataset'
(Apart of Bid Data Analysis)"""

import pandas as pd

# %%
data = pd.read_csv('London Housing Data.csv')

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# 5       6/1/1995  city of london          94901  E09000001         17.0
# 6       7/1/1995  city of london         110128  E09000001         13.0
# 7       8/1/1995  city of london         112329  E09000001         14.0
# 8       9/1/1995  city of london         104473  E09000001         17.0
# 9      10/1/1995  city of london         108038  E09000001         14.0
# 10     11/1/1995  city of london         117636  E09000001         11.0
# 11     12/1/1995  city of london         127232  E09000001         18.0
# ...

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
#convert the 'Date' column to Date-Time format.
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date = pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
#Add a new column 'year' in the dataframe, which contains years only
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data['year'] = data.date.dt.year
data['month'] = data.date.dt.month

# %%
data
# Out:
#             date  month            area  average_price       code  \
# 0     1995-01-01      1  city of london          91449  E09000001
# 1     1995-02-01      2  city of london          82203  E09000001
# 2     1995-03-01      3  city of london          79121  E09000001
# 3     1995-04-01      4  city of london          77101  E09000001
# 4     1995-05-01      5  city of london          84409  E09000001
# 5     1995-06-01      6  city of london          94901  E09000001
# 6     1995-07-01      7  city of london         110128  E09000001
# 7     1995-08-01      8  city of london         112329  E09000001
# 8     1995-09-01      9  city of london         104473  E09000001
# 9     1995-10-01     10  city of london         108038  E09000001
# 10    1995-11-01     11  city of london         117636  E09000001
# 11    1995-12-01     12  city of london         127232  E09000001
# 12    1996-01-01      1  city of london         108999  E09000001
# ...

# %%
data.insert(1 , 'month' , data.date.dt.month )

# %%
#Remove the columns 'year' and 'month' from the dataframe.
data.drop( ['month', 'year'], axis = 1, inplace = True)

# %%
data.head(20)
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
# 5  1995-06-01  city of london          94901  E09000001         17.0
# 6  1995-07-01  city of london         110128  E09000001         13.0
# 7  1995-08-01  city of london         112329  E09000001         14.0
# 8  1995-09-01  city of london         104473  E09000001         17.0
# 9  1995-10-01  city of london         108038  E09000001         14.0
# 10 1995-11-01  city of london         117636  E09000001         11.0
# 11 1995-12-01  city of london         127232  E09000001         18.0
# 12 1996-01-01  city of london         108999  E09000001         17.0
# ...

# %%
#show all the records where 'No. of Crimes' is 0. And, how many such records are there?
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data[data['no_of_crimes'] == 0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# 77  2001-06-01  city of london         242435  E09000001         36.0
# 78  2001-07-01  city of london         230700  E09000001         40.0
# 79  2001-08-01  city of london         231632  E09000001         30.0
# 80  2001-09-01  city of london         229806  E09000001         30.0
# 81  2001-10-01  city of london         263887  E09000001         26.0
# 82  2001-11-01  city of london         346458  E09000001         15.0
# 83  2001-12-01  city of london         362204  E09000001         17.0
# ...

# %%
len(data[data['no_of_crimes'] == 0])
# Out:
# 104

# %%
#what is the maximum and the minimum 'average_price' per year in england?
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data['year'] = data.date.dt.year

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
df1 = data[data.area == 'england']

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# 13253 1995-06-01  england          53735  E92000001      72640.0
# 13254 1995-07-01  england          53901  E92000001      64242.0
# 13255 1995-08-01  england          53600  E92000001      69269.0
# 13256 1995-09-01  england          53309  E92000001      67251.0
# 13257 1995-10-01  england          52845  E92000001      61264.0
# 13258 1995-11-01  england          52788  E92000001      63955.0
# 13259 1995-12-01  england          52922  E92000001      69345.0
# 13260 1996-01-01  england          52333  E92000001      48694.0
# ...

# %%
df1.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
#what is the Maximum and the Minimum No. of Crimes Recorded per area?
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
data.groupby('area').no_of_crimes.max().sort_values(ascending = True)
# Out:
# area
# city of london              10.0
# kingston upon thames      1379.0
# sutton                    1425.0
# richmond upon thames      1551.0
# merton                    1623.0
# harrow                    1763.0
# bexley                    1914.0
# havering                  1956.0
# barking and dagenham      2049.0
# redbridge                 2560.0
# bromley                   2637.0
# hammersmith and fulham    2645.0
# kensington and chelsea    2778.0
# enfield                   2798.0
# lewisham                  2813.0
# hounslow                  2817.0
# hillingdon                2819.0
# greenwich                 2853.0
# barnet                    2893.0
# brent                     2937.0
# waltham forest            2941.0
# wandsworth                3051.0
# haringey                  3199.0
# croydon                   3263.0
# tower hamlets             3316.0
# islington                 3384.0
# ealing                    3401.0
# hackney                   3466.0
# ...

# %%
data.groupby('area').no_of_crimes.min()
# Out:
# area
# barking and dagenham      1217.0
# barnet                    1703.0
# bexley                     860.0
# brent                     1850.0
# bromley                   1441.0
# camden                    2079.0
# city of london               0.0
# croydon                   2031.0
# ealing                    1871.0
# east midlands                NaN
# east of england              NaN
# enfield                   1635.0
# england                      NaN
# greenwich                 1513.0
# hackney                   1870.0
# hammersmith and fulham    1323.0
# haringey                  1536.0
# harrow                     937.0
# havering                  1130.0
# hillingdon                1445.0
# hounslow                  1529.0
# inner london                 NaN
# islington                 1871.0
# kensington and chelsea    1347.0
# kingston upon thames       692.0
# lambeth                   2381.0
# lewisham                  1675.0
# london                       NaN
# ...

# %%
#Show the total count of records of each area, where average price is less than 100000.
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
data[data.average_price < 100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# waltham forest           64
# bexley                   64
# lewisham                 62
# havering                 60
# greenwich                59
# south east               59
# croydon                  57
# sutton                   54
# enfield                  54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# hounslow                 41
# lambeth                  41
# brent                    40
# london                   39
# merton                   35
# bromley                  33
# haringey                 33
# ealing                   31
# ...
